# %%
lst=[0,1,"himanshu","bendale",3.5,4 , True,5]
print(lst)
print(type(lst))
for i in lst:
    print(i,type(i))
# Out:
# [0, 1, 'himanshu', 'bendale', 3.5, 4, True, 5]
# <class 'list'>
# 0 <class 'int'>
# 1 <class 'int'>
# himanshu <class 'str'>
# bendale <class 'str'>
# 3.5 <class 'float'>
# 4 <class 'int'>
# True <class 'bool'>
# 5 <class 'int'>

# %%
lst[6]
lst[6]=7
print(lst[1:])
# Out:
# [1, 'himanshu', 'himansuuu', 3.5, 4, 7, 5]

# %%
lst=[0,1,"himanshu","bendale",3.5,4 , True,5]
print(lst)
# Out:
# [0, 1, 'himanshu', 'bendale', 3.5, 4, True, 5]

# %%
lst=[0,1,"himanshu","bendale",3.5,4 , True,5]
print(lst[3])
print(lst[-5])
print(lst[2:5])  
lst[3]="himansuuu"
print(lst)
# Out:
# bendale
# bendale
# ['himanshu', 'bendale', 3.5]
# [0, 1, 'himanshu', 'himansuuu', 3.5, 4, True, 5]

# %%
lst.append("padhle")
lst.insert(2,"python")
print(lst)
# Out:
# [0, 1, 'python', 'himanshu', 'himansuuu', 3.5, 4, 7, 5, 'padhle']

# %%
lst=[0,1,"himanshu","bendale",3.5,4 , True,5]
print(lst)
# Out:
# [0, 1, 'himanshu', 'bendale', 3.5, 4, True, 5]

# %%
lst=[0,1,"himanshu","bendale",3.5,4 , True,5]
lst.remove(3.5)
a=lst.pop()
print(lst)
print(a)
# Out:
# [0, 1, 'himanshu', 'bendale', 4, True]
# 5

# %%
lst=[0,1,"himanshu","bendale",3.5,4 , "python",5,True]
for i in lst:
    print(f"{i} at location {lst.index(i)}")
# Out:
# 0 at location 0
# 1 at location 1
# himanshu at location 2
# bendale at location 3
# 3.5 at location 4
# 4 at location 5
# python at location 6
# 5 at location 7
# True at location 1
